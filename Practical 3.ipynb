# %% [markdown]
# # **For the same dataset which you read in second assignment. Plot the different plottings using matplotlib in python**

# %%
# !pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download vora1011/ipl-2008-to-2021-all-match-dataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# ...
#   0% 0.00/1.58M [00:00<?, ?B/s]
# 100% 1.58M/1.58M [00:00<00:00, 162MB/s]

# %%
# !unzip ipl-2008-to-2021-all-match-dataset.zip
# Out:
# Archive:  ipl-2008-to-2021-all-match-dataset.zip
#   inflating: IPL_Ball_by_Ball_2008_2022.csv
#   inflating: IPL_Matches_2008_2022.csv

# %%
import pandas as pd

df=pd.read_csv('IPL_Matches_2008_2022.csv')
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.shape
# Out:
# (950, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#parsing the dates
df['Date'] = pd.to_datetime(df.Date)
df['Year'] = pd.DatetimeIndex(df.Date).year
df['Month'] = pd.DatetimeIndex(df.Date).month
df['Day'] = pd.DatetimeIndex(df.Date).day
df['Weekday'] = pd.DatetimeIndex(df.Date).weekday

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# Year                 0
# Month                0
# Day                  0
# Weekday              0
# dtype: int64

# %%
df[df['City'].isnull()]
# Out:
#           ID City       Date   Season  MatchNumber  \
# 134  1237181  NaN 2020-11-10  2020/21        Final
# 137  1237177  NaN 2020-11-05  2020/21  Qualifier 1
# 138  1216495  NaN 2020-11-03  2020/21           56
# 140  1216530  NaN 2020-11-01  2020/21           54
# 142  1216535  NaN 2020-10-31  2020/21           51
# 143  1216502  NaN 2020-10-31  2020/21           52
# 145  1216536  NaN 2020-10-29  2020/21           49
# 147  1216524  NaN 2020-10-27  2020/21           47
# 148  1216520  NaN 2020-10-26  2020/21           46
# 150  1216544  NaN 2020-10-25  2020/21           44
# 151  1216498  NaN 2020-10-24  2020/21           43
# 153  1216521  NaN 2020-10-23  2020/21           41
# 154  1216518  NaN 2020-10-22  2020/21           40
# 156  1216546  NaN 2020-10-20  2020/21           38
# 159  1216517  NaN 2020-10-18  2020/21           36
# 160  1216522  NaN 2020-10-17  2020/21           33
# 161  1216509  NaN 2020-10-17  2020/21           34
# ...

# %%
df['City'].fillna('Dubai',inplace=True)
df['City'].isnull().sum()
# Out:
# 0

# %%
df[df['Player_of_Match'].isnull()]
# Out:
#           ID       City       Date Season MatchNumber  \
# 205  1178424  Bengaluru 2019-04-30   2019          49
# 437   829813  Bangalore 2015-05-17   2015          55
# 464   829763  Bangalore 2015-04-29   2015          29
# 708   501265      Delhi 2011-05-21   2011          68
#
#                            Team1             Team2                  Venue  \
# 205  Royal Challengers Bangalore  Rajasthan Royals  M.Chinnaswamy Stadium
# 437  Royal Challengers Bangalore  Delhi Daredevils  M Chinnaswamy Stadium
# 464  Royal Challengers Bangalore  Rajasthan Royals  M Chinnaswamy Stadium
# 708             Delhi Daredevils     Pune Warriors       Feroz Shah Kotla
#
#                       TossWinner TossDecision  ... method Player_of_Match  \
# 205             Rajasthan Royals        field  ...    NaN             NaN
# 437  Royal Challengers Bangalore        field  ...    NaN             NaN
# 464             Rajasthan Royals        field  ...    NaN             NaN
# ...

# %%
df['Venue'].replace({'M.Chinnaswamy Stadium':'M Chinnaswamy Stadium'}, inplace=True)
df.replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)

# %%
df.drop([241,486,511,744], inplace=True)
df.isnull().sum()
# Out:
# ID                   0
# City                 0
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             927
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# Year                 0
# Month                0
# Day                  0
# Weekday              0
# dtype: int64

# %%
df[df['Margin'].isnull()]
# Out:
#           ID       City       Date   Season MatchNumber  \
# 114  1254077    Chennai 2021-04-25     2021          20
# 158  1216512  Abu Dhabi 2020-10-18  2020/21          35
# 159  1216517      Dubai 2020-10-18  2020/21          36
# 184  1216547      Dubai 2020-09-28  2020/21          10
# 192  1216493      Dubai 2020-09-20  2020/21           2
# 203  1178426     Mumbai 2019-05-02     2019          51
# 205  1178424  Bengaluru 2019-04-30     2019          49
# 244  1175365      Delhi 2019-03-30     2019          10
# 339  1082625     Rajkot 2017-04-29     2017          35
# 437   829813  Bangalore 2015-05-17     2015          55
# 464   829763  Bangalore 2015-04-29     2015          29
# 474   829741  Ahmedabad 2015-04-21     2015          18
# 533   729315  Abu Dhabi 2014-04-29     2014          19
# 608   598017  Bangalore 2013-04-16     2013          21
# 621   598004  Hyderabad 2013-04-07     2013           7
# 708   501265      Delhi 2011-05-21     2011          68
# ...

# %%
df['Margin'].fillna(0, inplace=True)

# %%
df.method.unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
df['method'].fillna('regular', inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          4
# WinningTeam        4
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    4
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# Year               0
# Month              0
# Day                0
# Weekday            0
# dtype: int64

# %%
df1=pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
df1.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
df1.shape
# Out:
# (225954, 17)

# %%
df1.info
# Out:
# <bound method DataFrame.info of              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
# ...

# %%
df1.replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)

# %%
df1.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
len(df1[df1.isWicketDelivery==0])
# Out:
# 214803

# %%
len(df1[df1.extras_run==0])
# Out:
# 213905

# %%
df1['kind'].fillna('NA',inplace=True)
df1['player_out'].fillna('NA',inplace=True)
df1['fielders_involved'].fillna('NA', inplace=True)
df1['extra_type'].fillna('NA', inplace=True)

# %%
df2 = df.merge(df1, on="ID")
df2.head()
# Out:
#         ID       City       Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad 2022-05-29   2022       Final  Rajasthan Royals
# 1  1312200  Ahmedabad 2022-05-29   2022       Final  Rajasthan Royals
# 2  1312200  Ahmedabad 2022-05-29   2022       Final  Rajasthan Royals
# 3  1312200  Ahmedabad 2022-05-29   2022       Final  Rajasthan Royals
# 4  1312200  Ahmedabad 2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 1  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 2  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 3  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 4  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision  ... extra_type batsman_run extras_run  total_run non_boundary  \
# ...

# %%
from pandas.core.indexes.interval import InvalidIndexError
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=14
matplotlib.rcParams['figure.figsize']=(9,5)
matplotlib.rcParams['figure.facecolor']='#00000000'

# %%
df.describe()
# Out:
#                  ID      Margin         Year       Month         Day  \
# count  9.460000e+02  946.000000   946.000000  946.000000  946.000000
# mean   8.305715e+05   16.712474  2015.003171    4.913319   15.821353
# std    3.379111e+05   21.541538     4.320615    1.699951    8.398589
# min    3.359820e+05    0.000000  2008.000000    3.000000    1.000000
# 25%    5.012612e+05    5.000000  2011.000000    4.000000    9.000000
# 50%    8.297400e+05    8.000000  2015.000000    5.000000   16.000000
# 75%    1.177638e+06   18.000000  2019.000000    5.000000   23.000000
# max    1.312200e+06  146.000000  2022.000000   11.000000   31.000000
#
#           Weekday
# count  946.000000
# mean     3.465116
# std      2.036531
# min      0.000000
# 25%      2.000000
# 50%      4.000000
# 75%      5.000000
# max      6.000000

# %%
df1.describe()
# Out:
#                  ID        innings          overs     ballnumber  \
# count  2.259540e+05  225954.000000  225954.000000  225954.000000
# mean   8.320470e+05       1.483868       9.185679       3.619750
# std    3.379542e+05       0.503104       5.681797       1.810633
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012620e+05       1.000000       4.000000       2.000000
# 50%    8.297370e+05       1.000000       9.000000       4.000000
# 75%    1.178395e+06       2.000000      14.000000       5.000000
# max    1.312200e+06       6.000000      19.000000      10.000000
#
#          batsman_run     extras_run     total_run   non_boundary  \
# count  225954.000000  225954.000000  225954.00000  225954.000000
# mean        1.243523       0.066907       1.31043       0.000093
# std         1.618166       0.341470       1.60605       0.009640
# min         0.000000       0.000000       0.00000       0.000000
# ...

# %%
df.describe(include=['O'])
# Out:
#           City Season MatchNumber                        Team1  \
# count      946    946         946                          946
# unique      33     15          80                           17
# top     Mumbai   2013       Final  Royal Challengers Bangalore
# freq       158     76          15                          126
#
#                  Team2                  Venue      TossWinner TossDecision  \
# count              946                    946             946          946
# unique              17                     48              17            2
# top     Mumbai Indians  M Chinnaswamy Stadium  Mumbai Indians        field
# freq               119                     80             123          596
#
#        SuperOver     WinningTeam    WonBy   method Player_of_Match  \
# count        942             942      946      946             942
# unique         2              17        4        2             260
# top            N  Mumbai Indians  Wickets  regular  AB de Villiers
# ...

# %%
df1.describe(include=['O'])
# Out:
#          batter    bowler non-striker extra_type player_out    kind  \
# count    225954    225954      225954     225954     225954  225954
# unique      605       472         595          6        574      11
# top     V Kohli  R Ashwin    S Dhawan         NA         NA      NA
# freq       5266      4024        5526     213905     214803  214803
#
#        fielders_involved     BattingTeam
# count             225954          225954
# unique               536              17
# top                   NA  Mumbai Indians
# freq              217966           27826

# %%
df.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          4
# WinningTeam        4
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    4
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# Year               0
# Month              0
# Day                0
# Weekday            0
# dtype: int64

# %%
played=list(df['Team1'])+list(df['Team2'])
sns.histplot(played)
plt.xticks(rotation=90)
plt.xlabel('Teams');

# %%
sns.histplot(df['WinningTeam'], color='orange')
plt.xticks(rotation=90);

# %%
sns.histplot(played)
sns.histplot(df['WinningTeam'], color='orange')
plt.xticks(rotation=90)
plt.legend(['Matches Played','Matches Won'])
plt.xlabel('Teams');

# %%
Player_of_Match=df.Player_of_Match.value_counts().head(10)
Player_of_Match
# Out:
# AB de Villiers    25
# CH Gayle          22
# DA Warner         18
# RG Sharma         18
# MS Dhoni          17
# YK Pathan         16
# SR Watson         16
# KA Pollard        14
# SK Raina          14
# V Kohli           14
# Name: Player_of_Match, dtype: int64

# %%
sns.barplot(x=Player_of_Match.index, y=Player_of_Match)
plt.xticks(rotation=60)
plt.ylabel('No. of Times Player of the Match')
plt.xlabel('Name Of the Player')
plt.title('Player of the Match Award', fontsize=20);

# %%
for i in df.Year.unique():
    print("Year :", i,'<', '='*50,'>')
    xdf=df[df.Year==i] #conditioning over the year
    plt.pie(xdf.WinningTeam.value_counts(),autopct="%1.1f%%" ) #plotting pie chart of the winner's value counts
    plt.legend(xdf.WinningTeam.value_counts().index,bbox_to_anchor=(2,1),loc='upper right', title='Teams in {}'.format(i))
    plt.show();
# Out:
# Year : 2022 < ================================================== >
# Year : 2021 < ================================================== >
# Year : 2020 < ================================================== >
# Year : 2019 < ================================================== >
# Year : 2018 < ================================================== >
# Year : 2017 < ================================================== >
# Year : 2016 < ================================================== >
# Year : 2015 < ================================================== >
# Year : 2014 < ================================================== >
# Year : 2013 < ================================================== >
# Year : 2012 < ================================================== >
# Year : 2011 < ================================================== >
# Year : 2010 < ================================================== >
# Year : 2009 < ================================================== >
# ...

# %%
df1.isnull().sum()
# Out:
# ID                   0
# innings              0
# overs                0
# ballnumber           0
# batter               0
# bowler               0
# non-striker          0
# extra_type           0
# batsman_run          0
# extras_run           0
# total_run            0
# non_boundary         0
# isWicketDelivery     0
# player_out           0
# kind                 0
# fielders_involved    0
# BattingTeam          0
# dtype: int64

# %%
xd=df1.groupby(['ID', 'overs','innings'], as_index=False)['total_run'].sum()
xd['overs']=xd['overs']+1
#boxplot for distribution
sns.boxplot(y=xd['total_run'], x=xd['overs'])
plt.title('Boxplot of Run Scored per Over')
plt.ylabel('Runs per Over')
plt.xlabel('Over');

# %%
minimum=xd.groupby('overs', as_index=False)['total_run'].min()
maximum=xd.groupby('overs', as_index=False)['total_run'].max()
mean=xd.groupby('overs', as_index=False)['total_run'].mean()

#plotting lineplot with maximum, minmum and mean
sns.lineplot(data=maximum, x='overs', y='total_run')
sns.lineplot(data=mean, x='overs', y='total_run')
sns.lineplot(data=minimum, x='overs', y='total_run')
plt.legend(['Maximum', 'Mean', 'Minimum'])
plt.title('Lineplot of Runs Scored per Over')
plt.xlabel('Over')
plt.ylabel('Runs per Over');

# %%
for i in df.WinningTeam.unique():
    xdf=df[df.WinningTeam==i] #conditioning over winning
    plt.pie(xdf.Venue.value_counts().head(5),autopct="%1.1f%%" ) #using piechart for plotting with value counts over
    plt.legend(xdf.Venue.value_counts().head(5).index, bbox_to_anchor=(1,1.5),loc='upper right', title=i)
    plt.show()
    print("*"*100);
# Out:
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ...

# %%
top_scorers={}
for i in list(df.Year.unique()): #using for loop for getting each year (season)
    xd=df2[df2.Year==i] #conditioning based on the season
    sd=xd.groupby(['batter'], as_index=False)['batsman_run'].sum().sort_values('batsman_run', ascending=False).head(1)
    #finding the top scorer each season and adding the to the dictionary created before
    top_scorers[(sd['batter'].iloc[0]+str(' ')+str(i))]=sd['batsman_run'].iloc[0]

# %%
x=list(top_scorers.keys())
y=list(top_scorers.values())

#plotting barplot of the top scorers for the respective season
sns.barplot(x=x, y=y )
plt.xticks(rotation=90)
plt.title('Highest Run Scorers in All Season', fontsize=20)
plt.ylabel('Run Scored', fontsize=15 )
plt.xlabel('Batsman', fontsize=15);

# %%
df1.isnull().sum()
# Out:
# ID                   0
# innings              0
# overs                0
# ballnumber           0
# batter               0
# bowler               0
# non-striker          0
# extra_type           0
# batsman_run          0
# extras_run           0
# total_run            0
# non_boundary         0
# isWicketDelivery     0
# player_out           0
# kind                 0
# fielders_involved    0
# BattingTeam          0
# dtype: int64

# %%
fd=df1[(df1.kind=='caught')]['fielders_involved'].value_counts().head(10)
fd
# Out:
# MS Dhoni          135
# KD Karthik        133
# AB de Villiers    120
# SK Raina          106
# KA Pollard         97
# RG Sharma          96
# V Kohli            93
# S Dhawan           93
# RV Uthappa         92
# RA Jadeja          84
# Name: fielders_involved, dtype: int64

# %%
sns.barplot(x=fd.index, y=fd)
plt.title('Top 10 Fielders')
plt.xlabel('Name of Fielders')
plt.ylabel('No. of Catches / Run Outs')
plt.xticks(rotation=70);
